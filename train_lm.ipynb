# %%
# !git clone https://github.com/krypticmouse/double-bind-training.git
# %cd double-bind-training
# Out:
# Cloning into 'double-bind-training'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 39 (delta 13), reused 29 (delta 6), pack-reused 0
# Unpacking objects: 100% (39/39), 494.68 KiB | 2.94 MiB/s, done.
# /content/double-bind-training

# %%
# !git checkout train-lm-adapter
# Out:
# Branch 'train-lm-adapter' set up to track remote branch 'train-lm-adapter' from 'origin'.
# Switched to a new branch 'train-lm-adapter'

# %%
! pip install adapter-transformers seqeval ptvsd wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting adapter-transformers
#   Downloading adapter_transformers-3.1.0-py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 42.6 MB/s eta 0:00:00
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ptvsd
#   Downloading ptvsd-4.3.2-py2.py3-none-any.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 78.1 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.13.9-py2.py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from adapter-transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from adapter-transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from adapter-transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from adapter-transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from adapter-transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 KB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from adapter-transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 84.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from adapter-transformers) (21.3)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.8/dist-packages (from seqeval) (1.0.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from wandb) (4.4.0)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 17.0 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb) (57.4.0)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.14.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 KB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb) (3.19.6)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.15.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->adapter-transformers) (3.0.9)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->adapter-transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->adapter-transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->adapter-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->adapter-transformers) (2.10)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 16.0 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: seqeval, pathtools
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16179 sha256=ec72b696f70e586fd82d171facf32d62af9583ec8f5b7738ffb1d13366e4e423
#   Stored in directory: /root/.cache/pip/wheels/ad/5c/ba/05fa33fa5855777b7d686e843ec07452f22a66a138e290e732
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=000018c43ab01ffdd2bbe666af52f055a3e854e04149360ef6607fd1bf0265ab
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built seqeval pathtools
# Installing collected packages: tokenizers, pathtools, urllib3, smmap, setproctitle, ptvsd, docker-pycreds, sentry-sdk, gitdb, seqeval, huggingface-hub, GitPython, wandb, adapter-transformers
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed GitPython-3.1.30 adapter-transformers-3.1.0 docker-pycreds-0.4.0 gitdb-4.0.10 huggingface-hub-0.11.1 pathtools-0.1.2 ptvsd-4.3.2 sentry-sdk-1.14.0 seqeval-1.2.2 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.12.1 urllib3-1.26.14 wandb-0.13.9

# %%
import wandb
wandb.login()
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python train_lm_adapter.py \
    --model_name_or_path roberta-base \
    --dataset_name train.txt \
    --validation_file validation.txt \
    --per_device_train_batch_size 8 \
    --per_device_eval_batch_size 8 \
    --do_train \
    --do_eval \
    --output_dir /tmp/test-mlm
# Out:
# WARNING:__main__:Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# INFO:__main__:Training/evaluation parameters TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=-1,
# log_level=passive,
# log_level_replica=passive,
# log_on_each_node=True,
# logging_dir=/tmp/test-mlm/runs/Jan18_23-34-21_32f660ca261a,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=3.0,
# optim=adamw_hf,
# output_dir=/tmp/test-mlm,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=/tmp/test-mlm,
# save_on_each_node=False,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tf32=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# xpu_backend=None,
# )
# WARNING:datasets.builder:Using custom data configuration default-e9dea62205e2fa28
# INFO:datasets.info:Loading Dataset Infos from /usr/local/lib/python3.8/dist-packages/datasets/packaged_modules/text
# INFO:datasets.builder:Generating dataset text (/root/.cache/huggingface/datasets/text/default-e9dea62205e2fa28/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2)
# Downloading and preparing dataset text/default to /root/.cache/huggingface/datasets/text/default-e9dea62205e2fa28/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2...
# Downloading data files: 100% 2/2 [00:00<00:00, 11748.75it/s]
# INFO:datasets.download.download_manager:Downloading took 0.0 min
# INFO:datasets.download.download_manager:Checksum Computation took 0.0 min
# Extracting data files: 100% 2/2 [00:00<00:00, 1986.41it/s]
# INFO:datasets.utils.info_utils:Unable to verify checksums.
# INFO:datasets.builder:Generating train split
# INFO:datasets.builder:Generating validation split
# INFO:datasets.utils.info_utils:Unable to verify splits sizes.
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-e9dea62205e2fa28/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2. Subsequent calls will reuse this data.
# 100% 2/2 [00:00<00:00, 967.32it/s]
# Downloading: 100% 481/481 [00:00<00:00, 518kB/s]
# [INFO|configuration_utils.py:660] 2023-01-18 23:34:22,411 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/config.json
# [INFO|configuration_utils.py:712] 2023-01-18 23:34:22,412 >> Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# [INFO|tokenization_auto.py:427] 2023-01-18 23:34:22,544 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# [INFO|configuration_utils.py:660] 2023-01-18 23:34:22,666 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/config.json
# [INFO|configuration_utils.py:712] 2023-01-18 23:34:22,667 >> Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# Downloading: 100% 899k/899k [00:00<00:00, 6.20MB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 3.20MB/s]
# Downloading: 100% 1.36M/1.36M [00:00<00:00, 7.78MB/s]
# [INFO|tokenization_utils_base.py:1775] 2023-01-18 23:34:24,362 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/vocab.json
# [INFO|tokenization_utils_base.py:1775] 2023-01-18 23:34:24,362 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/merges.txt
# [INFO|tokenization_utils_base.py:1775] 2023-01-18 23:34:24,362 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/tokenizer.json
# [INFO|tokenization_utils_base.py:1775] 2023-01-18 23:34:24,362 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1775] 2023-01-18 23:34:24,362 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1775] 2023-01-18 23:34:24,362 >> loading file tokenizer_config.json from cache at None
# [INFO|configuration_utils.py:660] 2023-01-18 23:34:24,363 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/config.json
# [INFO|configuration_utils.py:712] 2023-01-18 23:34:24,364 >> Model config RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.24.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# Downloading: 100% 501M/501M [00:07<00:00, 70.7MB/s]
# [INFO|modeling_utils.py:2158] 2023-01-18 23:34:31,774 >> loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--roberta-base/snapshots/ff46155979338ff8063cdad90908b498ab91b181/pytorch_model.bin
# [INFO|modeling_utils.py:2608] 2023-01-18 23:34:33,623 >> All model checkpoint weights were used when initializing RobertaForMaskedLM.
#
# [INFO|modeling_utils.py:2616] 2023-01-18 23:34:33,623 >> All the weights of RobertaForMaskedLM were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForMaskedLM for predictions without further training.
# Running tokenizer on every text in dataset:   0% 0/31 [00:00<?, ?ba/s]INFO:datasets.arrow_dataset:Caching processed dataset at /root/.cache/huggingface/datasets/text/default-e9dea62205e2fa28/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2/cache-ab8d8dd937964cfd.arrow
# Running tokenizer on every text in dataset: 100% 31/31 [00:02<00:00, 11.74ba/s]
# Running tokenizer on every text in dataset:   0% 0/2 [00:00<?, ?ba/s]INFO:datasets.arrow_dataset:Caching processed dataset at /root/.cache/huggingface/datasets/text/default-e9dea62205e2fa28/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2/cache-0c9a3b445e3c99e8.arrow
# Running tokenizer on every text in dataset: 100% 2/2 [00:00<00:00, 14.26ba/s]
# Grouping texts in chunks of 512:   0% 0/31 [00:00<?, ?ba/s]INFO:datasets.arrow_dataset:Caching processed dataset at /root/.cache/huggingface/datasets/text/default-e9dea62205e2fa28/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2/cache-fe41aff3d4d9de55.arrow
# Grouping texts in chunks of 512: 100% 31/31 [00:02<00:00, 12.34ba/s]
# Grouping texts in chunks of 512:   0% 0/2 [00:00<?, ?ba/s]INFO:datasets.arrow_dataset:Caching processed dataset at /root/.cache/huggingface/datasets/text/default-e9dea62205e2fa28/0.0.0/cb1e9bd71a82ad27976be3b12b407850fe2837d80c22c5e03a28949843a8ace2/cache-0bdff28027758e36.arrow
# Grouping texts in chunks of 512: 100% 2/2 [00:00<00:00, 13.00ba/s]
# run_mlm.py:570: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("accuracy")
# INFO:datasets.utils.file_utils:https://raw.githubusercontent.com/huggingface/datasets/2.8.0/metrics/accuracy/accuracy.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpks9yg6q0
# Downloading builder script: 4.21kB [00:00, 3.57MB/s]
# INFO:datasets.utils.file_utils:storing https://raw.githubusercontent.com/huggingface/datasets/2.8.0/metrics/accuracy/accuracy.py in cache at /root/.cache/huggingface/datasets/downloads/e721a999ec4f00e18d4a90c8d1f4175ac106c340b0b4e4fcab61fe208ba19846.32b3507481ea2e26fd6a2b34c9976e9da377302faaf35089eb1cd971d41bb0ff.py
# INFO:datasets.utils.file_utils:creating metadata file for /root/.cache/huggingface/datasets/downloads/e721a999ec4f00e18d4a90c8d1f4175ac106c340b0b4e4fcab61fe208ba19846.32b3507481ea2e26fd6a2b34c9976e9da377302faaf35089eb1cd971d41bb0ff.py
# [INFO|trainer.py:725] 2023-01-18 23:34:43,726 >> The following columns in the training set don't have a corresponding argument in `RobertaForMaskedLM.forward` and have been ignored: special_tokens_mask. If special_tokens_mask are not expected by `RobertaForMaskedLM.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# [INFO|trainer.py:1608] 2023-01-18 23:34:43,734 >> ***** Running training *****
# [INFO|trainer.py:1609] 2023-01-18 23:34:43,734 >>   Num examples = 3178
# [INFO|trainer.py:1610] 2023-01-18 23:34:43,734 >>   Num Epochs = 3
# [INFO|trainer.py:1611] 2023-01-18 23:34:43,734 >>   Instantaneous batch size per device = 8
# [INFO|trainer.py:1612] 2023-01-18 23:34:43,734 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:1613] 2023-01-18 23:34:43,734 >>   Gradient Accumulation steps = 1
# [INFO|trainer.py:1614] 2023-01-18 23:34:43,734 >>   Total optimization steps = 1194
# [INFO|trainer.py:1615] 2023-01-18 23:34:43,735 >>   Number of trainable parameters = 124697433
#   0% 0/1194 [00:00<?, ?it/s][WARNING|logging.py:281] 2023-01-18 23:34:43,753 >> You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 2.299, 'learning_rate': 2.906197654941374e-05, 'epoch': 1.26}
#  42% 500/1194 [09:13<12:45,  1.10s/it][INFO|trainer.py:2678] 2023-01-18 23:43:56,966 >> Saving model checkpoint to /tmp/test-mlm/checkpoint-500
# [INFO|configuration_utils.py:447] 2023-01-18 23:43:56,967 >> Configuration saved in /tmp/test-mlm/checkpoint-500/config.json
# [INFO|modeling_utils.py:1624] 2023-01-18 23:43:58,559 >> Model weights saved in /tmp/test-mlm/checkpoint-500/pytorch_model.bin
# [INFO|tokenization_utils_base.py:2125] 2023-01-18 23:43:58,559 >> tokenizer config file saved in /tmp/test-mlm/checkpoint-500/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2132] 2023-01-18 23:43:58,560 >> Special tokens file saved in /tmp/test-mlm/checkpoint-500/special_tokens_map.json
#  47% 563/1194 [10:28<11:34,  1.10s/it]
